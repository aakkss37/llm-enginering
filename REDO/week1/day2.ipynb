# %% [markdown]
# ## First - let's talk about the Chat Completions API
#
# 1. The simplest way to call an LLM
# 2. It's called Chat Completions because it's saying: "here is a conversation, please predict what should come next"
# 3. The Chat Completions API was invented by OpenAI, but it's so popular that everybody uses it!
# 4. Now a days almost every LLM provides chat completion API

# %%
import os
from dotenv import load_dotenv

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
import requests

headers = {"Authorization": f"Bearer {api_key}", "Content-Type": "application/json"}

payload = {
    "model": "gpt-5-nano",
    "messages": [
        {"role": "user", "content": "It is very important to check "}]
}

response = requests.post(
    "https://api.openai.com/v1/chat/completions",
    headers=headers,
    json=payload
)

response.json()

##################################################################
### NOTE FOR ME: This chat completion API doesn't work as its name suggests
##################################################################
# Out:
# {'id': 'chatcmpl-DGAbGrCW4FqMWmtp5ndj7uLUR80Kw',
#  'object': 'chat.completion',
#  'created': 1772746366,
#  'model': 'gpt-5-nano-2025-08-07',
#  'choices': [{'index': 0,
#    'message': {'role': 'assistant',
# ...

# %%
response.json()["choices"][0]["message"]["content"]
# Out:
# 'I’m not sure what you want to check. Could you tell me the context ( proofreading, auditing, testing, data validation, etc.)? I can tailor a checklist or fix the sentence.\n\nIf you want a general reference, here’s a concise checklist you can adapt:\n- Define the objective and scope\n- Identify criteria and standards to meet\n- Verify accuracy and completeness\n- Check for consistency across items\n- Assess risks and potential errors\n- Ensure compliance with requirements, privacy, and security\n- Confirm data quality (validity, integrity, timeliness)\n- Review dependencies and impact\n- Ensure proper documentation and traceability\n- Obtain necessary sign-offs\n- Plan a re-check after remedies\n\nIf you’re looking for grammar suggestions, here are alternatives to “It is very important to check”:\n- It is crucial to verify\n- It is essential to check\n- It is important to confirm\n- It is important to verify the details\n\nShare more details and I’ll tailor it precisely.'

# %% [markdown]
# ## Same can be done by off course OpenAI library

# %%
# Create OpenAI client

from openai import OpenAI
openai = OpenAI()

response = openai.chat.completions.create(model="gpt-5-nano", messages=[{"role": "user", "content": "Tell me a fun fact"}])

response.choices[0].message.content
# Out:
# 'Fun fact: On Venus, a day is longer than a year. It takes about 243 Earth days to rotate once (and it spins backward), while it only takes about 225 Earth days to orbit the Sun.'

# %% [markdown]
# ## Lets do the same with local host running ollama

# %%
from openai import OpenAI
ollama = OpenAI(
    base_url="http://localhost:11434/v1",
    api_key="ollama:local" # For local models, the API key can be any random string"
)

response = ollama.chat.completions.create(model="llama3.2", messages=[{"role": "user", "content": "Tell me a fun fact"}])
response.choices[0].message.content
# Out:
# 'Here\'s a fun fact:\n\nDid you know that there is a species of jellyfish that is immune to pain? The Turritopsis dohrnii, also known as the "immortal jellyfish," can transform its body into a younger state through a process called transdifferentiation. This means it can essentially revert back to its polyp stage and grow a new adult jellyfish from itself, making it theoretically "immune" to aging and, by extension, pain! Isn\'t that mind-blowing?'
